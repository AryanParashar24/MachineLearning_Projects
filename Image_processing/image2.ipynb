# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("Sample.png")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (443, 615, 4)

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=615x443>

# %%
red = arr[:, :, 0]

# %%
plt.imshow(red)

# %%
work = arr.copy()

# %%
work[:, :, [1, 2]] = 0

# %%
plt.imshow(work)
