# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# pil = Image.open("tony.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (1511, 850, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x1511>

# %%
cut = arr[:250, :250]

# %%
plt.imshow(cut)
